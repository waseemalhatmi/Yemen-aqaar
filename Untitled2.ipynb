# %% [markdown]
# <a href="https://colab.research.google.com/github/waseemalhatmi/Yemen-aqaar/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("waseem")
# Out:
# waseem

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/waseemalhatmi/atr-perfume-platform.git
# Out:
# Cloning into 'atr-perfume-platform'...
# remote: Enumerating objects: 702, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 702 (delta 125), reused 137 (delta 69), pack-reused 478 (from 1)
# Receiving objects: 100% (702/702), 6.13 MiB | 19.85 MiB/s, done.
# Resolving deltas: 100% (319/319), done.

# %%
# %cd atr-perfume-platform
# Out:
# [Errno 2] No such file or directory: 'atr-perfume-platform'
# /content/atr-perfume-platform

# %%
# !find .
# Out:
# .
# ./Dockerfile
# ./Procfile
# ./implementation_checklist.md
# ./.node-version
# ./runtime.txt
# ./requirements-sync.txt
# ./act.bat
# ./config.py
# ./project_guide.md
# ./ui_plan.md
# ./tests
# ./tests/test_items_listing.py
# ./tests/conftest.py
# ./tests/test_csrf_security.py
# ./tests/test_admin_authorization.py
# ./tests/test_sensitive_routes_smoke.py
# ./tests/test_auth.py
# ./deact.bat
# ./.dockerignore
# ./requirements.txt
# ./images
# ./images/photo-1541643600914-78b084683601.jfif
# ./images/photo-1594035910387-fea47794261f.jfif
# ./images/photo-1523293182086-7651a899d37f.jfif
# ./images/photo-1541643600914-78b084683601 (1).jfif
# ./images/photo-1587017539504-67cfbddac569.jfif
# ./images/photo-1592945403244-b3fbafd7f539.jfif
# ./.git
# ./.git/logs
# ./.git/logs/refs
# ./.git/logs/refs/remotes
# ./.git/logs/refs/remotes/origin
# ./.git/logs/refs/remotes/origin/HEAD
# ./.git/logs/refs/heads
# ./.git/logs/refs/heads/main
# ./.git/logs/HEAD
# ./.git/packed-refs
# ...

# %%
# !cp -r /content/atr-perfume-platform /content/drive/MyDrive/

# %%
# !ls /content/drive/MyDrive/
# Out:
#  atr-perfume-platform
# 'Colab Notebooks'
#  places_basic.csv
# 'waseemalhatmi '
# 'waseemalhatmi  (1)'
# 'تحسين جدول محفزات النظام الأكاديمي.gsheet'
# 'تحسين مخطط الحالة الأكاديمية للطالب.gsheet'
# 'حالات الطالب الأكاديمية في جدول.gsheet'
# 'حالات ومحفزات الطالب الجامعي (1).gsheet'
# 'حالات ومحفزات الطالب الجامعي.gsheet'
# 'مخطط حالة الطالب الجامعي.gsheet'
